# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1" 
import ast
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
from keras import backend as K
from keras import Model
from keras import optimizers
from keras.legacy import interfaces
from keras.utils.generic_utils import get_custom_objects
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Dropout, Flatten, Activation, GlobalAveragePooling2D, BatchNormalization
from keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from keras.models import Sequential
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.optimizers import Adam
from keras.utils.training_utils import multi_gpu_model

from keras.optimizers import SGD
from keras import callbacks
from data import *
from keras_helper import *

from keras.applications import Xception
from keras.applications.xception import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
def image_generator_xd(size, batchsize, lw=2, 
                       df_path = '../input/train_all.csv', time_color=True, preprocess_input = None,
                       channel = 1, mixup = 0, center = False):
    while True:
        for df in pd.read_csv(df_path, chunksize=batchsize):
            df['drawing'] = df['drawing'].apply(json.loads)
            x = np.zeros((len(df), size, size, channel), dtype=np.uint8)
            for i, raw_strokes in enumerate(df.drawing.values):
                x[i, :, :, :] = draw_cv2_parts_opt(raw_strokes, size=size, 
                                             lw=lw, center = center)
            
            if 'word' in df:
                y = keras.utils.to_categorical(df.word, num_classes=NCATS)
                if preprocess_input is not None:
                    x = preprocess_input(x.astype(np.float32)).astype(np.float32)

                yield x, y  
            else:
                if preprocess_input is not None:
                    x = preprocess_input(x.astype(np.float32)).astype(np.float32)
                yield x
            
def df_to_image_array_xd(df, size, lw=2, 
                         time_color=True, preprocess_input = None,
                         channel = 1, center = False):
    df['drawing'] = df['drawing'].apply(json.loads)
    x = np.zeros((len(df), size, size, channel ), dtype=np.uint8)
    for i, raw_strokes in enumerate(df.drawing.values):
        x[i, :, :, :] = draw_cv2_parts_opt(raw_strokes, size=size, 
                                     lw=lw, center = center)
    if preprocess_input is not None:
        print('x shape',x.shape, 'x max', x.max())
        x = preprocess_input(x.astype(np.float32)).astype(np.float32)
    return x

# %%
# TOT = 35534421
TOT = 46613580 - 340000
EPOCHS = 70
size = 71
batchsize = 340
lw = 6
channel = 3
STEPS = TOT / EPOCHS / batchsize
NCATS = 340
mixup = 0
center = False
optimizer = 'adam'
cb = 'raw'

# %%
K.clear_session()
# model = Xception(input_shape=(size, size, channel), weights=None, classes=NCATS)
model = Xception(input_shape=(None,None,3), weights=None, classes=NCATS)

if optimizer == 'sgd':
    opt = SGD(0.002, momentum=0.9, nesterov=True)
    opt = NormalizedOptimizer(opt, normalization='l2')
elif optimizer == 'adam':
    opt = Adam(lr=0.0005)

# model = multi_gpu_model(model, gpus=2)

# model.load_weights('models/xception128_parts2_lw6_balance_0_adam_parts.model')

model.compile(optimizer=opt, loss='categorical_crossentropy',
              metrics=[categorical_crossentropy, categorical_accuracy, top_3_accuracy])
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, None, None, 3 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, None, None, 3 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, None, None, 6 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, None, None, 6 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, None, None, 6 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, None, None, 1 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, None, None, 1 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, None, None, 1 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, None, None, 1 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, None, None, 1 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 1 8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, None, None, 1 0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 1 512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 1 0           block2_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, None, None, 1 0           add_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, None, None, 2 33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, None, None, 2 1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, None, None, 2 0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, None, None, 2 67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, None, None, 2 1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 2 32768       add_1[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, None, None, 2 0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 2 1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           block3_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, None, None, 7 188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, None, None, 7 0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 7 186368      add_2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, None, None, 7 0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 7 2912        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 7 0           block4_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, None, None, 7 0           add_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, None, None, 7 0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, None, None, 7 0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 7 0           block5_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, None, None, 7 0           add_4[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, None, None, 7 0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, None, None, 7 0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 7 0           block6_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, None, None, 7 0           add_5[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, None, None, 7 0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, None, None, 7 0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 7 0           block7_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, None, None, 7 0           add_6[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, None, None, 7 0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, None, None, 7 0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 7 0           block8_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, None, None, 7 0           add_7[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, None, None, 7 536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, None, None, 7 2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, None, None, 7 0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, None, None, 7 536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, None, None, 7 2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, None, None, 7 0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, None, None, 7 536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, None, None, 7 2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 7 0           block9_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, None, None, 7 0           add_8[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, None, None, 7 536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, None, None, 7 2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, None, None, 7 0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, None, None, 7 536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, None, None, 7 2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, None, None, 7 0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, None, None, 7 536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, None, None, 7 2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 7 0           block10_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, None, None, 7 0           add_9[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, None, None, 7 536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, None, None, 7 2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, None, None, 7 0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, None, None, 7 536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, None, None, 7 2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, None, None, 7 0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, None, None, 7 536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, None, None, 7 2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 7 0           block11_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, None, None, 7 0           add_10[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, None, None, 7 536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, None, None, 7 2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, None, None, 7 0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, None, None, 7 536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, None, None, 7 2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, None, None, 7 0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, None, None, 7 536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, None, None, 7 2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 7 0           block12_sepconv3_bn[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, None, None, 7 0           add_11[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, None, None, 7 536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, None, None, 7 2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, None, None, 7 0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, None, None, 1 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, None, None, 1 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 745472      add_11[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, None, None, 1 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 1 4096        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           block13_pool[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, None, None, 1 1582080     add_12[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, None, None, 1 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, None, None, 1 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, None, None, 2 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, None, None, 2 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, None, None, 2 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 340)          696660      avg_pool[0][0]
# ==================================================================================================
# Total params: 21,558,140
# Trainable params: 21,503,612
# Non-trainable params: 54,528
# __________________________________________________________________________________________________
# None

# %%
valid_df = pd.read_csv('../input/valid.csv')
x_valid = df_to_image_array_xd(valid_df, size, lw=lw, preprocess_input=preprocess_input, 
                               channel=channel, center = center)
y_valid = keras.utils.to_categorical(valid_df.word, num_classes=NCATS)
# Out:
# x shape (34000, 71, 71, 3) x max 255

# %%
print(x_valid.shape, y_valid.shape)
print('Validation array memory {:.2f} GB'.format(x_valid.nbytes / 1024.**3 ))
# Out:
# (34000, 71, 71, 3) (34000, 340)
# Validation array memory 1.92 GB

# %%
train_datagen = image_generator_xd(df_path = '../input/train_all.csv', 
                                   size=size, batchsize=batchsize, lw=lw, 
                                   preprocess_input=preprocess_input,
                                  channel=channel, mixup=mixup, center=center)

# %%
model_prefix = 'xception{}_parts_opt_lw{}_balance_{}_{}'.format(size, lw, mixup, optimizer, cb)
if center:
    model_prefix += '_center'
if channel == 3:
    model_prefix += '_parts'
print(model_prefix)
check_path = "./models/{}.model".format(model_prefix)
fold = 9
if cb == 'raw':
    callbks = [
        ReduceLROnPlateau(monitor='val_categorical_accuracy', factor=0.5, patience=5,
                          min_delta=0.005, mode='max', cooldown=3, verbose=1),
        callbacks.ModelCheckpoint(check_path,
                                    monitor='val_categorical_accuracy', 
                                    mode = 'max', 
                                  save_best_only=True, save_weights_only=True,
                                  verbose=1),
        callbacks.TensorBoard(log_dir='./log/{}'.format(model_prefix)),
        EarlyStopping(monitor='val_categorical_accuracy', mode='max',patience=20, verbose=1)
    ]
elif cb == 'snap':
    snapshot = SnapshotCallbackBuilder(nb_epochs=EPOCHS,
                                       nb_snapshots=3,
                                       size = size,
                                       init_lr=1e-3, 
                                       fold=fold)

    callbks = snapshot.get_callbacks(model_prefix = model_prefix)
# Out:
# xception71_parts_opt_lw6_balance_0_adam_parts

# %%
hists = []
hist = model.fit_generator(
    train_datagen, steps_per_epoch=STEPS, epochs=EPOCHS, verbose=1,
    validation_data=(x_valid, y_valid),
    callbacks = callbks
)
# Out:
# Epoch 1/70
# 1945/1944 [==============================] - 1126s 579ms/step - loss: 1.8871 - categorical_crossentropy: 1.8871 - categorical_accuracy: 0.5505 - top_3_accuracy: 0.7426 - val_loss: 1.5652 - val_categorical_crossentropy: 1.5652 - val_categorical_accuracy: 0.6129 - val_top_3_accuracy: 0.8084
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.61291, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 2/70
# 1945/1944 [==============================] - 1127s 579ms/step - loss: 1.2945 - categorical_crossentropy: 1.2945 - categorical_accuracy: 0.6740 - top_3_accuracy: 0.8496 - val_loss: 1.4839 - val_categorical_crossentropy: 1.4839 - val_categorical_accuracy: 0.6268 - val_top_3_accuracy: 0.8193
#
# Epoch 00002: val_categorical_accuracy improved from 0.61291 to 0.62682, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 3/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 1.1644 - categorical_crossentropy: 1.1644 - categorical_accuracy: 0.7040 - top_3_accuracy: 0.8698 - val_loss: 1.2733 - val_categorical_crossentropy: 1.2733 - val_categorical_accuracy: 0.6784 - val_top_3_accuracy: 0.8536
#
# Epoch 00003: val_categorical_accuracy improved from 0.62682 to 0.67844, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 4/70
# 1945/1944 [==============================] - 1126s 579ms/step - loss: 1.0926 - categorical_crossentropy: 1.0926 - categorical_accuracy: 0.7207 - top_3_accuracy: 0.8808 - val_loss: 1.4250 - val_categorical_crossentropy: 1.4250 - val_categorical_accuracy: 0.6392 - val_top_3_accuracy: 0.8292
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.67844
# Epoch 5/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 1.0457 - categorical_crossentropy: 1.0457 - categorical_accuracy: 0.7323 - top_3_accuracy: 0.8873 - val_loss: 1.1361 - val_categorical_crossentropy: 1.1361 - val_categorical_accuracy: 0.7080 - val_top_3_accuracy: 0.8744
#
# Epoch 00005: val_categorical_accuracy improved from 0.67844 to 0.70797, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 6/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 1.0081 - categorical_crossentropy: 1.0081 - categorical_accuracy: 0.7410 - top_3_accuracy: 0.8926 - val_loss: 1.0794 - val_categorical_crossentropy: 1.0794 - val_categorical_accuracy: 0.7231 - val_top_3_accuracy: 0.8834
#
# Epoch 00006: val_categorical_accuracy improved from 0.70797 to 0.72306, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 7/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.9784 - categorical_crossentropy: 0.9784 - categorical_accuracy: 0.7484 - top_3_accuracy: 0.8969 - val_loss: 1.1162 - val_categorical_crossentropy: 1.1162 - val_categorical_accuracy: 0.7129 - val_top_3_accuracy: 0.8771
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.72306
# Epoch 8/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.9557 - categorical_crossentropy: 0.9557 - categorical_accuracy: 0.7533 - top_3_accuracy: 0.9001 - val_loss: 0.9882 - val_categorical_crossentropy: 0.9882 - val_categorical_accuracy: 0.7451 - val_top_3_accuracy: 0.8959
#
# Epoch 00008: val_categorical_accuracy improved from 0.72306 to 0.74512, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 9/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.9326 - categorical_crossentropy: 0.9326 - categorical_accuracy: 0.7591 - top_3_accuracy: 0.9029 - val_loss: 0.9861 - val_categorical_crossentropy: 0.9861 - val_categorical_accuracy: 0.7473 - val_top_3_accuracy: 0.8968
#
# Epoch 00009: val_categorical_accuracy improved from 0.74512 to 0.74732, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 10/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.9170 - categorical_crossentropy: 0.9170 - categorical_accuracy: 0.7630 - top_3_accuracy: 0.9052 - val_loss: 1.4273 - val_categorical_crossentropy: 1.4273 - val_categorical_accuracy: 0.6329 - val_top_3_accuracy: 0.8312
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.74732
# Epoch 11/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.9034 - categorical_crossentropy: 0.9034 - categorical_accuracy: 0.7669 - top_3_accuracy: 0.9072 - val_loss: 0.9346 - val_categorical_crossentropy: 0.9346 - val_categorical_accuracy: 0.7611 - val_top_3_accuracy: 0.9029
#
# Epoch 00011: val_categorical_accuracy improved from 0.74732 to 0.76115, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 12/70
# 1945/1944 [==============================] - 1123s 577ms/step - loss: 0.8928 - categorical_crossentropy: 0.8928 - categorical_accuracy: 0.7682 - top_3_accuracy: 0.9089 - val_loss: 0.9997 - val_categorical_crossentropy: 0.9997 - val_categorical_accuracy: 0.7455 - val_top_3_accuracy: 0.8936
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.76115
# Epoch 13/70
# 1945/1944 [==============================] - 1125s 578ms/step - loss: 0.8805 - categorical_crossentropy: 0.8805 - categorical_accuracy: 0.7715 - top_3_accuracy: 0.9105 - val_loss: 1.3294 - val_categorical_crossentropy: 1.3294 - val_categorical_accuracy: 0.6582 - val_top_3_accuracy: 0.8500
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.76115
# Epoch 14/70
# 1945/1944 [==============================] - 1125s 578ms/step - loss: 0.8735 - categorical_crossentropy: 0.8735 - categorical_accuracy: 0.7734 - top_3_accuracy: 0.9114 - val_loss: 0.9042 - val_categorical_crossentropy: 0.9042 - val_categorical_accuracy: 0.7657 - val_top_3_accuracy: 0.9068
#
# Epoch 00014: val_categorical_accuracy improved from 0.76115 to 0.76574, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 15/70
# 1945/1944 [==============================] - 1125s 578ms/step - loss: 0.8624 - categorical_crossentropy: 0.8624 - categorical_accuracy: 0.7759 - top_3_accuracy: 0.9126 - val_loss: 1.0329 - val_categorical_crossentropy: 1.0329 - val_categorical_accuracy: 0.7320 - val_top_3_accuracy: 0.8904
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.76574
# Epoch 16/70
# 1945/1944 [==============================] - 1126s 579ms/step - loss: 0.8571 - categorical_crossentropy: 0.8571 - categorical_accuracy: 0.7774 - top_3_accuracy: 0.9135 - val_loss: 0.9349 - val_categorical_crossentropy: 0.9349 - val_categorical_accuracy: 0.7593 - val_top_3_accuracy: 0.9032
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.76574
# Epoch 17/70
# 1945/1944 [==============================] - 1125s 578ms/step - loss: 0.8096 - categorical_crossentropy: 0.8096 - categorical_accuracy: 0.7889 - top_3_accuracy: 0.9198 - val_loss: 0.8360 - val_categorical_crossentropy: 0.8360 - val_categorical_accuracy: 0.7824 - val_top_3_accuracy: 0.9157
#
# Epoch 00017: val_categorical_accuracy improved from 0.76574 to 0.78244, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 18/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.8008 - categorical_crossentropy: 0.8008 - categorical_accuracy: 0.7914 - top_3_accuracy: 0.9204 - val_loss: 0.8149 - val_categorical_crossentropy: 0.8149 - val_categorical_accuracy: 0.7894 - val_top_3_accuracy: 0.9189
#
# Epoch 00018: val_categorical_accuracy improved from 0.78244 to 0.78944, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 19/70
# 1945/1944 [==============================] - 1123s 577ms/step - loss: 0.7944 - categorical_crossentropy: 0.7944 - categorical_accuracy: 0.7940 - top_3_accuracy: 0.9215 - val_loss: 0.8124 - val_categorical_crossentropy: 0.8124 - val_categorical_accuracy: 0.7914 - val_top_3_accuracy: 0.9192
#
# Epoch 00019: val_categorical_accuracy improved from 0.78944 to 0.79135, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 20/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7850 - categorical_crossentropy: 0.7850 - categorical_accuracy: 0.7960 - top_3_accuracy: 0.9225 - val_loss: 0.8045 - val_categorical_crossentropy: 0.8045 - val_categorical_accuracy: 0.7927 - val_top_3_accuracy: 0.9190
#
# Epoch 00020: val_categorical_accuracy improved from 0.79135 to 0.79268, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 21/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7844 - categorical_crossentropy: 0.7844 - categorical_accuracy: 0.7956 - top_3_accuracy: 0.9225 - val_loss: 0.8030 - val_categorical_crossentropy: 0.8030 - val_categorical_accuracy: 0.7916 - val_top_3_accuracy: 0.9204
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.79268
# Epoch 22/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7853 - categorical_crossentropy: 0.7853 - categorical_accuracy: 0.7955 - top_3_accuracy: 0.9226 - val_loss: 0.7950 - val_categorical_crossentropy: 0.7950 - val_categorical_accuracy: 0.7942 - val_top_3_accuracy: 0.9218
#
# Epoch 00022: val_categorical_accuracy improved from 0.79268 to 0.79421, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 23/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7775 - categorical_crossentropy: 0.7775 - categorical_accuracy: 0.7973 - top_3_accuracy: 0.9233 - val_loss: 0.7950 - val_categorical_crossentropy: 0.7950 - val_categorical_accuracy: 0.7946 - val_top_3_accuracy: 0.9203
#
# Epoch 00023: val_categorical_accuracy improved from 0.79421 to 0.79462, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 24/70
# 1945/1944 [==============================] - 1123s 577ms/step - loss: 0.7775 - categorical_crossentropy: 0.7775 - categorical_accuracy: 0.7975 - top_3_accuracy: 0.9236 - val_loss: 0.7902 - val_categorical_crossentropy: 0.7902 - val_categorical_accuracy: 0.7962 - val_top_3_accuracy: 0.9213
#
# Epoch 00024: val_categorical_accuracy improved from 0.79462 to 0.79624, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 25/70
# 1945/1944 [==============================] - 1125s 578ms/step - loss: 0.7746 - categorical_crossentropy: 0.7746 - categorical_accuracy: 0.7985 - top_3_accuracy: 0.9238 - val_loss: 0.7864 - val_categorical_crossentropy: 0.7864 - val_categorical_accuracy: 0.7963 - val_top_3_accuracy: 0.9225
#
# Epoch 00025: val_categorical_accuracy improved from 0.79624 to 0.79632, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 26/70
# 1945/1944 [==============================] - 1123s 578ms/step - loss: 0.7722 - categorical_crossentropy: 0.7722 - categorical_accuracy: 0.7987 - top_3_accuracy: 0.9244 - val_loss: 0.8267 - val_categorical_crossentropy: 0.8267 - val_categorical_accuracy: 0.7849 - val_top_3_accuracy: 0.9159
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.79632
# Epoch 27/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7694 - categorical_crossentropy: 0.7694 - categorical_accuracy: 0.7995 - top_3_accuracy: 0.9247 - val_loss: 0.7811 - val_categorical_crossentropy: 0.7811 - val_categorical_accuracy: 0.7953 - val_top_3_accuracy: 0.9234
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.79632
# Epoch 28/70
# 1945/1944 [==============================] - 1123s 577ms/step - loss: 0.7621 - categorical_crossentropy: 0.7621 - categorical_accuracy: 0.8005 - top_3_accuracy: 0.9255 - val_loss: 0.9138 - val_categorical_crossentropy: 0.9138 - val_categorical_accuracy: 0.7606 - val_top_3_accuracy: 0.9055
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.79632
# Epoch 29/70
# 1945/1944 [==============================] - 1125s 578ms/step - loss: 0.7426 - categorical_crossentropy: 0.7426 - categorical_accuracy: 0.8062 - top_3_accuracy: 0.9275 - val_loss: 0.7449 - val_categorical_crossentropy: 0.7449 - val_categorical_accuracy: 0.8076 - val_top_3_accuracy: 0.9270
#
# Epoch 00029: val_categorical_accuracy improved from 0.79632 to 0.80759, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 30/70
# 1945/1944 [==============================] - 1123s 578ms/step - loss: 0.7348 - categorical_crossentropy: 0.7348 - categorical_accuracy: 0.8079 - top_3_accuracy: 0.9294 - val_loss: 0.7435 - val_categorical_crossentropy: 0.7435 - val_categorical_accuracy: 0.8071 - val_top_3_accuracy: 0.9284
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.80759
# Epoch 31/70
# 1945/1944 [==============================] - 1125s 578ms/step - loss: 0.7318 - categorical_crossentropy: 0.7318 - categorical_accuracy: 0.8085 - top_3_accuracy: 0.9294 - val_loss: 0.7413 - val_categorical_crossentropy: 0.7413 - val_categorical_accuracy: 0.8069 - val_top_3_accuracy: 0.9283
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.80759
# Epoch 32/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7414 - categorical_crossentropy: 0.7414 - categorical_accuracy: 0.8074 - top_3_accuracy: 0.9282 - val_loss: 0.7401 - val_categorical_crossentropy: 0.7401 - val_categorical_accuracy: 0.8077 - val_top_3_accuracy: 0.9278
#
# Epoch 00032: val_categorical_accuracy improved from 0.80759 to 0.80771, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 33/70
# 1945/1944 [==============================] - 1123s 578ms/step - loss: 0.7349 - categorical_crossentropy: 0.7349 - categorical_accuracy: 0.8079 - top_3_accuracy: 0.9289 - val_loss: 0.7395 - val_categorical_crossentropy: 0.7395 - val_categorical_accuracy: 0.8067 - val_top_3_accuracy: 0.9284
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.80771
# Epoch 34/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7304 - categorical_crossentropy: 0.7304 - categorical_accuracy: 0.8090 - top_3_accuracy: 0.9289 - val_loss: 0.7377 - val_categorical_crossentropy: 0.7377 - val_categorical_accuracy: 0.8071 - val_top_3_accuracy: 0.9280
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.80771
# Epoch 35/70
# 1945/1944 [==============================] - 1123s 577ms/step - loss: 0.7292 - categorical_crossentropy: 0.7292 - categorical_accuracy: 0.8091 - top_3_accuracy: 0.9296 - val_loss: 0.7314 - val_categorical_crossentropy: 0.7314 - val_categorical_accuracy: 0.8089 - val_top_3_accuracy: 0.9293
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00035: val_categorical_accuracy improved from 0.80771 to 0.80888, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 36/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7212 - categorical_crossentropy: 0.7212 - categorical_accuracy: 0.8116 - top_3_accuracy: 0.9304 - val_loss: 0.7214 - val_categorical_crossentropy: 0.7214 - val_categorical_accuracy: 0.8127 - val_top_3_accuracy: 0.9304
#
# Epoch 00036: val_categorical_accuracy improved from 0.80888 to 0.81271, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 37/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7168 - categorical_crossentropy: 0.7168 - categorical_accuracy: 0.8127 - top_3_accuracy: 0.9312 - val_loss: 0.7201 - val_categorical_crossentropy: 0.7201 - val_categorical_accuracy: 0.8129 - val_top_3_accuracy: 0.9306
#
# Epoch 00037: val_categorical_accuracy improved from 0.81271 to 0.81285, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 38/70
# 1945/1944 [==============================] - 1123s 578ms/step - loss: 0.7159 - categorical_crossentropy: 0.7159 - categorical_accuracy: 0.8128 - top_3_accuracy: 0.9310 - val_loss: 0.7166 - val_categorical_crossentropy: 0.7166 - val_categorical_accuracy: 0.8136 - val_top_3_accuracy: 0.9308
#
# Epoch 00038: val_categorical_accuracy improved from 0.81285 to 0.81362, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 39/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7149 - categorical_crossentropy: 0.7149 - categorical_accuracy: 0.8135 - top_3_accuracy: 0.9315 - val_loss: 0.7169 - val_categorical_crossentropy: 0.7169 - val_categorical_accuracy: 0.8131 - val_top_3_accuracy: 0.9305
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.81362
# Epoch 40/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7145 - categorical_crossentropy: 0.7145 - categorical_accuracy: 0.8135 - top_3_accuracy: 0.9316 - val_loss: 0.7170 - val_categorical_crossentropy: 0.7170 - val_categorical_accuracy: 0.8133 - val_top_3_accuracy: 0.9304
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.81362
# Epoch 41/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7081 - categorical_crossentropy: 0.7081 - categorical_accuracy: 0.8155 - top_3_accuracy: 0.9322 - val_loss: 0.7163 - val_categorical_crossentropy: 0.7163 - val_categorical_accuracy: 0.8139 - val_top_3_accuracy: 0.9308
#
# Epoch 00041: val_categorical_accuracy improved from 0.81362 to 0.81385, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 42/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7085 - categorical_crossentropy: 0.7085 - categorical_accuracy: 0.8149 - top_3_accuracy: 0.9320 - val_loss: 0.7142 - val_categorical_crossentropy: 0.7142 - val_categorical_accuracy: 0.8147 - val_top_3_accuracy: 0.9318
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00042: val_categorical_accuracy improved from 0.81385 to 0.81471, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 43/70
# 1945/1944 [==============================] - 1123s 578ms/step - loss: 0.7071 - categorical_crossentropy: 0.7071 - categorical_accuracy: 0.8150 - top_3_accuracy: 0.9321 - val_loss: 0.7087 - val_categorical_crossentropy: 0.7087 - val_categorical_accuracy: 0.8159 - val_top_3_accuracy: 0.9316
#
# Epoch 00043: val_categorical_accuracy improved from 0.81471 to 0.81585, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 44/70
# 1945/1944 [==============================] - 1123s 577ms/step - loss: 0.7069 - categorical_crossentropy: 0.7069 - categorical_accuracy: 0.8151 - top_3_accuracy: 0.9323 - val_loss: 0.7069 - val_categorical_crossentropy: 0.7069 - val_categorical_accuracy: 0.8164 - val_top_3_accuracy: 0.9322
#
# Epoch 00044: val_categorical_accuracy improved from 0.81585 to 0.81638, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 45/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7014 - categorical_crossentropy: 0.7014 - categorical_accuracy: 0.8165 - top_3_accuracy: 0.9329 - val_loss: 0.7062 - val_categorical_crossentropy: 0.7062 - val_categorical_accuracy: 0.8161 - val_top_3_accuracy: 0.9314
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.81638
# Epoch 46/70
# 1945/1944 [==============================] - 1123s 577ms/step - loss: 0.6996 - categorical_crossentropy: 0.6996 - categorical_accuracy: 0.8168 - top_3_accuracy: 0.9332 - val_loss: 0.7064 - val_categorical_crossentropy: 0.7064 - val_categorical_accuracy: 0.8176 - val_top_3_accuracy: 0.9320
#
# Epoch 00046: val_categorical_accuracy improved from 0.81638 to 0.81756, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 47/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.6971 - categorical_crossentropy: 0.6971 - categorical_accuracy: 0.8173 - top_3_accuracy: 0.9334 - val_loss: 0.7043 - val_categorical_crossentropy: 0.7043 - val_categorical_accuracy: 0.8166 - val_top_3_accuracy: 0.9322
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.81756
# Epoch 48/70
# 1945/1944 [==============================] - 1125s 578ms/step - loss: 0.6991 - categorical_crossentropy: 0.6991 - categorical_accuracy: 0.8167 - top_3_accuracy: 0.9333 - val_loss: 0.7059 - val_categorical_crossentropy: 0.7059 - val_categorical_accuracy: 0.8160 - val_top_3_accuracy: 0.9323
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.81756
# Epoch 49/70
# 1945/1944 [==============================] - 1123s 577ms/step - loss: 0.7005 - categorical_crossentropy: 0.7005 - categorical_accuracy: 0.8162 - top_3_accuracy: 0.9331 - val_loss: 0.7039 - val_categorical_crossentropy: 0.7039 - val_categorical_accuracy: 0.8170 - val_top_3_accuracy: 0.9333
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.81756
# Epoch 50/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7004 - categorical_crossentropy: 0.7004 - categorical_accuracy: 0.8173 - top_3_accuracy: 0.9332 - val_loss: 0.7016 - val_categorical_crossentropy: 0.7016 - val_categorical_accuracy: 0.8174 - val_top_3_accuracy: 0.9336
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.81756
# Epoch 51/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.6973 - categorical_crossentropy: 0.6973 - categorical_accuracy: 0.8179 - top_3_accuracy: 0.9336 - val_loss: 0.7004 - val_categorical_crossentropy: 0.7004 - val_categorical_accuracy: 0.8179 - val_top_3_accuracy: 0.9337
#
# Epoch 00051: val_categorical_accuracy improved from 0.81756 to 0.81788, saving model to ./models/xception71_parts_opt_lw6_balance_0_adam_parts.model
# Epoch 52/70
# 1945/1944 [==============================] - 1124s 578ms/step - loss: 0.7009 - categorical_crossentropy: 0.7009 - categorical_accuracy: 0.8173 - top_3_accuracy: 0.9328 - val_loss: 0.7005 - val_categorical_crossentropy: 0.7005 - val_categorical_accuracy: 0.8171 - val_top_3_accuracy: 0.9333
#
# Epoch 00052: val_categorical_accuracy did not improve from 0.81788
# Epoch 53/70
#  810/1944 [===========>..................] - ETA: 10:47 - loss: 0.6974 - categorical_crossentropy: 0.6974 - categorical_accuracy: 0.8176 - top_3_accuracy: 0.9331

# %%
test = pd.read_csv('../input/test_simplified.csv')
test.head()
x_test = df_to_image_array_xd(test, size, lw=lw, 
                              preprocess_input=preprocess_input,
                             channel=channel, center = center)
print(test.shape, x_test.shape)
print('Test array memory {:.2f} GB'.format(x_test.nbytes / 1024.**3 ))

np_classes = np.load('../input/classes.npy')
id2cat = {k: cat.replace(' ', '_') for k, cat in enumerate(np_classes)}

# %%
def doodle_predict(model, model_path, x_test):
    model.load_weights(model_path)

    test_predictions = model.predict(x_test, batch_size=128, verbose=1)
    top3 = preds2catids(test_predictions)
    top3cats = top3.replace(id2cat)
    test['word'] = top3cats['a'] + ' ' + top3cats['b'] + ' ' + top3cats['c']
    submission = test[['key_id', 'word']]

    import kaggle_util
    kaggle_util.save_result(submission,  
                            '../result/{}.csv'.format(model_prefix), 
                            'quickdraw-doodle-recognition', 
                            send=True, index=False)

# %%
doodle_predict(model, check_path, x_test)
